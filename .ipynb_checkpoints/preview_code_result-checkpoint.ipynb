# %%
import pandas as pd
df = pd.read_csv("employee_salary.csv")

# %%
'''Q1'''
print("\n1.First 5 Records:")
print(df.head())
print("\n2.Last 5 Records:")
print(df.tail())
print("\n3.Dataset Shape:", df.shape)
print("4.Number of Records:", df.shape[0])
print("5.Number of Features:", df.shape[1])
# Out:
# 1.First 5 Records:
#    EmployeeID   Name Department  Age  Experience  Salary       City  \
# 0         101   John         HR   25           2   45000    Chennai
# 1         102  Smith         IT   30           5   55000  Bangalore
# 2         103  Alice    Finance   28           4   60000  Hyderabad
# 3         104    Bob  Marketing   35           8   70000     Mumbai
# 4         105  David         IT   29           6   65000       Pune
#
#   Performance
# 0        Good
# 1   Excellent
# 2        Good
# 3   Excellent
# 4     Average
#
# 2.Last 5 Records:
#     EmployeeID       Name Department  Age  Experience  Salary       City  \
# 15         116        Ava      Sales   26           2   49000      Delhi
# 16         117       Liam         IT   34           9   80000       Pune
# 17         118  Charlotte    Finance   30           6   69000  Bangalore
# 18         119      James         HR   25           2   46000    Chennai
# 19         120     Amelia  Marketing   32           8   73000    Kolkata
#
#    Performance
# 15        Good
# 16   Excellent
# 17        Good
# 18     Average
# 19   Excellent
#
# 3.Dataset Shape: (20, 8)
# 4.Number of Records: 20
# 5.Number of Features: 8

# %%
'''Q2'''
print("\n6.Column Names:")
print(df.columns)
print("\n7.Data Types:")
print(df.dtypes)
print("\n8.Dataset Information:")
df.info()
print("\n9.Descriptive Statistics:")
print(df.describe())
print("\n10.Average Employee Salary:")
print(df["Salary"].mean())
print("\n11.Standard Deviation:")
print(df.std(numeric_only=True))
# Out:
# 6.Column Names:
# Index(['EmployeeID', 'Name', 'Department', 'Age', 'Experience', 'Salary',
#        'City', 'Performance'],
#       dtype='str')
#
# 7.Data Types:
# EmployeeID     int64
# Name             str
# Department       str
# Age            int64
# Experience     int64
# Salary         int64
# City             str
# Performance      str
# dtype: object
#
# 8.Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   20 non-null     int64
#  1   Name         20 non-null     str
#  2   Department   20 non-null     str
#  3   Age          20 non-null     int64
#  4   Experience   20 non-null     int64
#  5   Salary       20 non-null     int64
#  6   City         20 non-null     str
#  7   Performance  20 non-null     str
# dtypes: int64(4), str(4)
# memory usage: 1.4 KB
#
# 9.Descriptive Statistics:
#        EmployeeID        Age  Experience        Salary
# count    20.00000  20.000000   20.000000     20.000000
# mean    110.50000  29.100000    4.800000  60400.000000
# std       5.91608   3.160613    2.375312  11175.160425
# min     101.00000  24.000000    1.000000  42000.000000
# 25%     105.75000  26.750000    2.750000  49750.000000
# 50%     110.50000  29.000000    5.000000  61000.000000
# 75%     115.25000  31.250000    6.250000  69250.000000
# max     120.00000  35.000000    9.000000  80000.000000
#
# 10.Average Employee Salary:
# 60400.0
#
# 11.Standard Deviation:
# EmployeeID        5.916080
# Age               3.160613
# Experience        2.375312
# Salary        11175.160425
# dtype: float64

# %%
'''Q3'''
print("\n12.Number of Missing Values:")
print(df.isnull().sum())
print("\n13.Percentage of Missing Values:")
print((df.isnull().sum() / len(df)) * 100)
print("\n14.Number of Duplicate Records:")
print(df.duplicated().sum())
print("\n15.Dataset Size Before Cleaning:", len(df))
df_cleaned = df.drop_duplicates()
print("16.Dataset Size After Cleaning:", len(df_cleaned))
print("\n17.Column with Highest Missing Values:")
print(df.isnull().sum().idxmax())
# Out:
# 12.Number of Missing Values:
# EmployeeID     0
# Name           0
# Department     0
# Age            0
# Experience     0
# Salary         0
# City           0
# Performance    0
# dtype: int64
#
# 13.Percentage of Missing Values:
# EmployeeID     0.0
# Name           0.0
# Department     0.0
# Age            0.0
# Experience     0.0
# Salary         0.0
# City           0.0
# Performance    0.0
# dtype: float64
#
# 14.Number of Duplicate Records:
# 0
#
# 15.Dataset Size Before Cleaning: 20
# 16.Dataset Size After Cleaning: 20
#
# 17.Column with Highest Missing Values:
# EmployeeID
